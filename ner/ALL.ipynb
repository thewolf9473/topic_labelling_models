# %% [markdown]
# ## adapted asr to csv

# %%
import pandas as pd
f=open('/content/adapted_asr.txt','r')
data=f.readlines()
f.close()

# %%
val=[]
for i in data:
  arr=i.split(' ')
  callid=arr[0]
  trans=' '.join(arr[1:])
  val.append([callid,trans])
df=pd.DataFrame(val,columns=['CALLID','adaptedasr_trans'])

# %%
df.shape
# Out:
# (2364, 2)

# %%
df.head()

# %%
df1=pd.read_csv('yaml_extracted.csv')
df1.head()
# Out:
#                                               CALLID  \
# 0  cs01M-RE4971679ba55a28460b19a5635505f241_B_000...
# 1  de01M-RE4971679ba55a28460b19a5635505f241_A_002...
# 2  cs01M-RE4971679ba55a28460b19a5635505f241_B_006...
# 3  na-RE4971679ba55a28460b19a5635505f241_B_007396...
# 4                 ro01M-CHR3_2620740_B_013481_015204
#
#                         transcript                                    ner
# 0                             yes?                                     []
# 1  ten past seven on the fiftieth.  ['ten past seven', 'on the fiftieth']
# 2                            okay.                                     []
# 3                              NaN                                     []
# 4                           hello.                                     []

# %%
for i , row in df1.iterrows():
  text=row['transcript']
  ner=row['ner']

  if isinstance(ner,str):
    ner=literal_eval(ner)
    newner= list((map(lambda x: x.lower(),ner)))
  if isinstance(text,str):
    text=text.lower()

  df1.at[i,'transcript']=text
  df1.at[i,'ner']=newner
df1.head()
# Out:
#                                               CALLID  \
# 0  cs01M-RE4971679ba55a28460b19a5635505f241_B_000...
# 1  de01M-RE4971679ba55a28460b19a5635505f241_A_002...
# 2  cs01M-RE4971679ba55a28460b19a5635505f241_B_006...
# 3  na-RE4971679ba55a28460b19a5635505f241_B_007396...
# 4                 ro01M-CHR3_2620740_B_013481_015204
#
#                         transcript                                ner
# 0                             yes?                                 []
# 1  ten past seven on the fiftieth.  [ten past seven, on the fiftieth]
# 2                            okay.                                 []
# 3                              NaN                                 []
# 4                           hello.                                 []

# %%
newdf=pd.merge(df,df1,on='CALLID',how='left')
newdf.shape
# Out:
# (2364, 4)

# %%
newdf.to_csv('adapted_basic.csv',index=False)

# %% [markdown]
# ## flair model analysis import

# %%
# !pip install flair --quiet
# !pip install conllu==4.4.2

from flair.data import Sentence
from flair.models import SequenceTagger
# load tagger
# flair/ner-english-ontonotes-large => onto notes
# flair/ner-english-large => conll
tagger = SequenceTagger.load("flair/ner-english-ontonotes-large")
# Out:
#      |████████████████████████████████| 401 kB 5.2 MB/s
#      |████████████████████████████████| 1.6 MB 56.5 MB/s
#      |████████████████████████████████| 101 kB 11.1 MB/s
#      |████████████████████████████████| 788 kB 53.5 MB/s
#      |████████████████████████████████| 53 kB 1.3 MB/s
#      |████████████████████████████████| 981 kB 52.9 MB/s
#      |████████████████████████████████| 46 kB 3.5 MB/s
#      |████████████████████████████████| 1.2 MB 40.4 MB/s
#      |████████████████████████████████| 19.7 MB 320 kB/s
#      |████████████████████████████████| 4.4 MB 36.6 MB/s
#      |████████████████████████████████| 199 kB 52.4 MB/s
#      |████████████████████████████████| 62 kB 1.2 MB/s
#      |████████████████████████████████| 6.6 MB 36.1 MB/s
#      |████████████████████████████████| 596 kB 41.2 MB/s
#   Building wheel for mpld3 (setup.py) ... done
#   Building wheel for overrides (setup.py) ... done
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for langdetect (setup.py) ... done
#   Building wheel for pptree (setup.py) ... done
#   Building wheel for wikipedia-api (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.3.7 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 3.10.1 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting conllu==4.4.2
#   Downloading conllu-4.4.2-py2.py3-none-any.whl (15 kB)
# Installing collected packages: conllu
#   Attempting uninstall: conllu
#     Found existing installation: conllu 4.5.1
#     Uninstalling conllu-4.5.1:
#       Successfully uninstalled conllu-4.5.1
# Successfully installed conllu-4.4.2
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/file_download.py:563: FutureWarning: `cached_download` is the legacy way to download files from the HF hub, please consider upgrading to `hf_hub_download`
#   FutureWarning,
# Downloading:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# 2022-07-17 15:08:10,444 loading file /root/.flair/models/ner-english-ontonotes-large/2da6c2cdd76e59113033adf670340bfd820f0301ae2e39204d67ba2dc276cc28.ec1bdb304b6c66111532c3b1fc6e522460ae73f1901848a4d0362cdf9760edb1
# Downloading:   0%|          | 0.00/616 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/8.68M [00:00<?, ?B/s]
# 2022-07-17 15:08:29,541 SequenceTagger predicts: Dictionary with 76 tags: <unk>, O, B-CARDINAL, E-CARDINAL, S-PERSON, S-CARDINAL, S-PRODUCT, B-PRODUCT, I-PRODUCT, E-PRODUCT, B-WORK_OF_ART, I-WORK_OF_ART, E-WORK_OF_ART, B-PERSON, E-PERSON, S-GPE, B-DATE, I-DATE, E-DATE, S-ORDINAL, S-LANGUAGE, I-PERSON, S-EVENT, S-DATE, B-QUANTITY, E-QUANTITY, S-TIME, B-TIME, I-TIME, E-TIME, B-GPE, E-GPE, S-ORG, I-GPE, S-NORP, B-FAC, I-FAC, E-FAC, B-NORP, E-NORP, S-PERCENT, B-ORG, E-ORG, B-LANGUAGE, E-LANGUAGE, I-CARDINAL, I-ORG, S-WORK_OF_ART, I-QUANTITY, B-MONEY

# %%
df.to_csv('asrbaseline.csv',index=False)

# %%
import pandas as pd
df=pd.read_csv('/content/asr_results (baseline and boosted).csv')
df.head()
# Out:
#                                               CALLID  \
# 0  cs01M-RE00bcf8e1f2c6d1c6573f18ade20ec956_A_000...
# 1  cs01M-RE00bcf8e1f2c6d1c6573f18ade20ec956_A_015...
# 2  cs01M-RE0f4543b94c7a5953871ac37cbc47a25f_B_000...
# 3  cs01M-RE0f4543b94c7a5953871ac37cbc47a25f_B_004...
# 4  cs01M-RE17b84c6cb32b4392ba3096982d24fbba_B_000...
#
#                                               manual  \
# 0  hi i'm in brno we had coffee arranged everythi...
# 1  i do not know if i make it i'll call when i'm ...
# 2                                               hi\n
# 3  sorry look i'm out now jakub will call you and...
# 4                                          so what\n
#
#                                                  ASR  \
# 0  hi i'm in butter oh we had to go see it instea...
# 1  ah i don't know if i make it uh oklahoma but i...
# 2                                                i\n
# 3  sorry hello come out my uncle bill go through ...
# 4                                          so what\n
#
#                                          ASR_boosted       asr_ner  \
# 0  hi i'm in butter oh we have to go see it inste...           NaN
# 1  ah i don't know if i make it a oklahoma but i ...  ['oklahoma']
# 2                                                i\n           NaN
# 3  so they come out with my uncle bill go through...           NaN
# 4                                          so what\n           NaN
#
#   asr_boosted_ner                                    transcript_yaml  \
# 0             NaN  hi. I'm in Brno. we had coffee. arranged every...
# 1    ['oklahoma']  I do not know if I make it. I'll call when I'm...
# 2             NaN                                                hi.
# 3             NaN  sorry. look I'm out now. Jakub will call you a...
# 4             NaN                                           so what?
#
#                              ner_yaml
# 0  ['Brno', 'Prague', 'half an hour']
# 1                          ['Prague']
# 2                                  []
# 3                           ['Jakub']
# 4                                  []

# %%
df=df[['CALLID','ASR','ASR_boosted','asr_ner','asr_boosted_ner']]

# %%
import numpy as np
df['asrboosted_person']=np.empty((len(df), 0)).tolist()
df['asrboosted_location']=np.empty((len(df), 0)).tolist()
df['asrboosted_time']=np.empty((len(df), 0)).tolist()
df.head()
# Out:
#                                               CALLID  \
# 0  cs01M-RE00bcf8e1f2c6d1c6573f18ade20ec956_A_000...
# 1  cs01M-RE00bcf8e1f2c6d1c6573f18ade20ec956_A_015...
# 2  cs01M-RE0f4543b94c7a5953871ac37cbc47a25f_B_000...
# 3  cs01M-RE0f4543b94c7a5953871ac37cbc47a25f_B_004...
# 4  cs01M-RE17b84c6cb32b4392ba3096982d24fbba_B_000...
#
#                                                  ASR  \
# 0  hi i'm in butter oh we had to go see it instea...
# 1  ah i don't know if i make it uh oklahoma but i...
# 2                                                i\n
# 3  sorry hello come out my uncle bill go through ...
# 4                                          so what\n
#
#                                          ASR_boosted       asr_ner  \
# 0  hi i'm in butter oh we have to go see it inste...           NaN
# 1  ah i don't know if i make it a oklahoma but i ...  ['oklahoma']
# 2                                                i\n           NaN
# 3  so they come out with my uncle bill go through...           NaN
# 4                                          so what\n           NaN
#
#   asr_boosted_ner asrboosted_person asrboosted_location asrboosted_time
# 0             NaN                []                  []              []
# 1    ['oklahoma']                []                  []              []
# 2             NaN                []                  []              []
# 3             NaN                []                  []              []
# 4             NaN                []                  []              []

# %%
print('STARTING')
p='ASR_boosted'
mp='asrboosted_person'
ml='asrboosted_location'
mt='asrboosted_time'

for index,row in df.iterrows():
  manual_p=[]
  manual_l=[]
  manual_t=[]

  id=row['CALLID']
  manual_text=row[p]
  if isinstance(manual_text,str):
    sentence = Sentence(manual_text)
    tagger.predict(sentence)

    for entity in sentence.get_spans('ner'):
      ner_entity=entity.text
      ner_type=str(entity.labels[0].value)


      if ner_type in  ['PERSON']:
        manual_p.append(ner_entity)
      
      if ner_type in  ['LOC','ORG','GPE']:
        manual_l.append(ner_entity)
      
      if ner_type in  ['DATE','TIME']:
        manual_t.append(ner_entity)
        
  df.at[index,mp]=manual_p
  df.at[index,ml]=manual_l
  df.at[index,mt]=manual_t

  print(f'{index}/{df.shape[0]} done √√')

print('ENDING')
# Out:
# STARTING
# 0/2364 done √√
# 1/2364 done √√
# 2/2364 done √√
# 3/2364 done √√
# 4/2364 done √√
# 5/2364 done √√
# 6/2364 done √√
# 7/2364 done √√
# 8/2364 done √√
# 9/2364 done √√
# 10/2364 done √√
# 11/2364 done √√
# 12/2364 done √√
# 13/2364 done √√
# 14/2364 done √√
# 15/2364 done √√
# 16/2364 done √√
# 17/2364 done √√
# 18/2364 done √√
# 19/2364 done √√
# 20/2364 done √√
# 21/2364 done √√
# 22/2364 done √√
# 23/2364 done √√
# 24/2364 done √√
# 25/2364 done √√
# 26/2364 done √√
# 27/2364 done √√
# 28/2364 done √√
# 29/2364 done √√
# 30/2364 done √√
# 31/2364 done √√
# 32/2364 done √√
# 33/2364 done √√
# 34/2364 done √√
# 35/2364 done √√
# 36/2364 done √√
# 37/2364 done √√
# 38/2364 done √√
# 39/2364 done √√
# 40/2364 done √√
# 41/2364 done √√
# 42/2364 done √√
# 43/2364 done √√
# 44/2364 done √√
# 45/2364 done √√
# 46/2364 done √√
# 47/2364 done √√
# 48/2364 done √√
# 49/2364 done √√
# 50/2364 done √√
# 51/2364 done √√
# 52/2364 done √√
# 53/2364 done √√
# 54/2364 done √√
# 55/2364 done √√
# 56/2364 done √√
# 57/2364 done √√
# 58/2364 done √√
# 59/2364 done √√
# 60/2364 done √√
# 61/2364 done √√
# 62/2364 done √√
# 63/2364 done √√
# 64/2364 done √√
# 65/2364 done √√
# 66/2364 done √√
# 67/2364 done √√
# 68/2364 done √√
# 69/2364 done √√
# 70/2364 done √√
# 71/2364 done √√
# 72/2364 done √√
# 73/2364 done √√
# 74/2364 done √√
# 75/2364 done √√
# 76/2364 done √√
# 77/2364 done √√
# 78/2364 done √√
# 79/2364 done √√
# 80/2364 done √√
# 81/2364 done √√
# 82/2364 done √√
# 83/2364 done √√
# 84/2364 done √√
# 85/2364 done √√
# 86/2364 done √√
# 87/2364 done √√
# 88/2364 done √√
# 89/2364 done √√
# 90/2364 done √√
# 91/2364 done √√
# 92/2364 done √√
# 93/2364 done √√
# 94/2364 done √√
# 95/2364 done √√
# 96/2364 done √√
# 97/2364 done √√
# 98/2364 done √√
# 99/2364 done √√
# 100/2364 done √√
# 101/2364 done √√
# 102/2364 done √√
# 103/2364 done √√
# 104/2364 done √√
# 105/2364 done √√
# 106/2364 done √√
# 107/2364 done √√
# 108/2364 done √√
# 109/2364 done √√
# 110/2364 done √√
# 111/2364 done √√
# 112/2364 done √√
# 113/2364 done √√
# 114/2364 done √√
# 115/2364 done √√
# 116/2364 done √√
# 117/2364 done √√
# 118/2364 done √√
# 119/2364 done √√
# 120/2364 done √√
# 121/2364 done √√
# 122/2364 done √√
# 123/2364 done √√
# 124/2364 done √√
# 125/2364 done √√
# 126/2364 done √√
# 127/2364 done √√
# 128/2364 done √√
# 129/2364 done √√
# 130/2364 done √√
# 131/2364 done √√
# 132/2364 done √√
# 133/2364 done √√
# 134/2364 done √√
# 135/2364 done √√
# 136/2364 done √√
# 137/2364 done √√
# 138/2364 done √√
# 139/2364 done √√
# 140/2364 done √√
# 141/2364 done √√
# 142/2364 done √√
# 143/2364 done √√
# 144/2364 done √√
# 145/2364 done √√
# 146/2364 done √√
# 147/2364 done √√
# 148/2364 done √√
# 149/2364 done √√
# 150/2364 done √√
# 151/2364 done √√
# 152/2364 done √√
# 153/2364 done √√
# 154/2364 done √√
# 155/2364 done √√
# 156/2364 done √√
# 157/2364 done √√
# 158/2364 done √√
# 159/2364 done √√
# 160/2364 done √√
# 161/2364 done √√
# 162/2364 done √√
# 163/2364 done √√
# 164/2364 done √√
# 165/2364 done √√
# 166/2364 done √√
# 167/2364 done √√
# 168/2364 done √√
# 169/2364 done √√
# 170/2364 done √√
# 171/2364 done √√
# 172/2364 done √√
# 173/2364 done √√
# 174/2364 done √√
# 175/2364 done √√
# 176/2364 done √√
# 177/2364 done √√
# 178/2364 done √√
# 179/2364 done √√
# 180/2364 done √√
# 181/2364 done √√
# 182/2364 done √√
# 183/2364 done √√
# 184/2364 done √√
# 185/2364 done √√
# 186/2364 done √√
# 187/2364 done √√
# 188/2364 done √√
# 189/2364 done √√
# 190/2364 done √√
# 191/2364 done √√
# 192/2364 done √√
# 193/2364 done √√
# 194/2364 done √√
# 195/2364 done √√
# 196/2364 done √√
# 197/2364 done √√
# 198/2364 done √√
# 199/2364 done √√
# 200/2364 done √√
# 201/2364 done √√
# 202/2364 done √√
# 203/2364 done √√
# 204/2364 done √√
# 205/2364 done √√
# 206/2364 done √√
# 207/2364 done √√
# 208/2364 done √√
# 209/2364 done √√
# 210/2364 done √√
# 211/2364 done √√
# 212/2364 done √√
# 213/2364 done √√
# 214/2364 done √√
# 215/2364 done √√
# 216/2364 done √√
# 217/2364 done √√
# 218/2364 done √√
# 219/2364 done √√
# 220/2364 done √√
# 221/2364 done √√
# 222/2364 done √√
# 223/2364 done √√
# 224/2364 done √√
# 225/2364 done √√
# 226/2364 done √√
# 227/2364 done √√
# 228/2364 done √√
# 229/2364 done √√
# 230/2364 done √√
# 231/2364 done √√
# 232/2364 done √√
# 233/2364 done √√
# 234/2364 done √√
# 235/2364 done √√
# 236/2364 done √√
# 237/2364 done √√
# 238/2364 done √√
# 239/2364 done √√
# 240/2364 done √√
# 241/2364 done √√
# 242/2364 done √√
# 243/2364 done √√
# 244/2364 done √√
# 245/2364 done √√
# 246/2364 done √√
# 247/2364 done √√
# 248/2364 done √√
# 249/2364 done √√
# 250/2364 done √√
# 251/2364 done √√
# 252/2364 done √√
# 253/2364 done √√
# 254/2364 done √√
# 255/2364 done √√
# 256/2364 done √√
# 257/2364 done √√
# 258/2364 done √√
# 259/2364 done √√
# 260/2364 done √√
# 261/2364 done √√
# 262/2364 done √√
# 263/2364 done √√
# 264/2364 done √√
# 265/2364 done √√
# 266/2364 done √√
# 267/2364 done √√
# 268/2364 done √√
# 269/2364 done √√
# 270/2364 done √√
# 271/2364 done √√
# 272/2364 done √√
# 273/2364 done √√
# 274/2364 done √√
# 275/2364 done √√
# 276/2364 done √√
# 277/2364 done √√
# 278/2364 done √√
# 279/2364 done √√
# 280/2364 done √√
# 281/2364 done √√
# 282/2364 done √√
# 283/2364 done √√
# 284/2364 done √√
# 285/2364 done √√
# 286/2364 done √√
# 287/2364 done √√
# 288/2364 done √√
# 289/2364 done √√
# 290/2364 done √√
# 291/2364 done √√
# 292/2364 done √√
# 293/2364 done √√
# 294/2364 done √√
# 295/2364 done √√
# 296/2364 done √√
# 297/2364 done √√
# 298/2364 done √√
# 299/2364 done √√
# 300/2364 done √√
# 301/2364 done √√
# 302/2364 done √√
# 303/2364 done √√
# 304/2364 done √√
# 305/2364 done √√
# 306/2364 done √√
# 307/2364 done √√
# 308/2364 done √√
# 309/2364 done √√
# 310/2364 done √√
# 311/2364 done √√
# 312/2364 done √√
# 313/2364 done √√
# 314/2364 done √√
# 315/2364 done √√
# 316/2364 done √√
# 317/2364 done √√
# 318/2364 done √√
# 319/2364 done √√
# 320/2364 done √√
# 321/2364 done √√
# 322/2364 done √√
# 323/2364 done √√
# 324/2364 done √√
# 325/2364 done √√
# 326/2364 done √√
# 327/2364 done √√
# 328/2364 done √√
# 329/2364 done √√
# 330/2364 done √√
# 331/2364 done √√
# 332/2364 done √√
# 333/2364 done √√
# 334/2364 done √√
# 335/2364 done √√
# 336/2364 done √√
# 337/2364 done √√
# 338/2364 done √√
# 339/2364 done √√
# 340/2364 done √√
# 341/2364 done √√
# 342/2364 done √√
# 343/2364 done √√
# 344/2364 done √√
# 345/2364 done √√
# 346/2364 done √√
# 347/2364 done √√
# 348/2364 done √√
# 349/2364 done √√
# 350/2364 done √√
# 351/2364 done √√
# 352/2364 done √√
# 353/2364 done √√
# 354/2364 done √√
# 355/2364 done √√
# 356/2364 done √√
# 357/2364 done √√
# 358/2364 done √√
# 359/2364 done √√
# 360/2364 done √√
# 361/2364 done √√
# 362/2364 done √√
# 363/2364 done √√
# 364/2364 done √√
# 365/2364 done √√
# 366/2364 done √√
# 367/2364 done √√
# 368/2364 done √√
# 369/2364 done √√
# 370/2364 done √√
# 371/2364 done √√
# 372/2364 done √√
# 373/2364 done √√
# 374/2364 done √√
# 375/2364 done √√
# 376/2364 done √√
# 377/2364 done √√
# 378/2364 done √√
# 379/2364 done √√
# 380/2364 done √√
# 381/2364 done √√
# 382/2364 done √√
# 383/2364 done √√
# 384/2364 done √√
# 385/2364 done √√
# 386/2364 done √√
# 387/2364 done √√
# 388/2364 done √√
# 389/2364 done √√
# 390/2364 done √√
# 391/2364 done √√
# 392/2364 done √√
# 393/2364 done √√
# 394/2364 done √√
# 395/2364 done √√
# 396/2364 done √√
# 397/2364 done √√
# 398/2364 done √√
# 399/2364 done √√
# 400/2364 done √√
# 401/2364 done √√
# 402/2364 done √√
# 403/2364 done √√
# 404/2364 done √√
# 405/2364 done √√
# 406/2364 done √√
# 407/2364 done √√
# 408/2364 done √√
# 409/2364 done √√
# 410/2364 done √√
# 411/2364 done √√
# 412/2364 done √√
# 413/2364 done √√
# 414/2364 done √√
# 415/2364 done √√
# 416/2364 done √√
# 417/2364 done √√
# 418/2364 done √√
# 419/2364 done √√
# 420/2364 done √√
# 421/2364 done √√
# 422/2364 done √√
# 423/2364 done √√
# 424/2364 done √√
# 425/2364 done √√
# 426/2364 done √√
# 427/2364 done √√
# 428/2364 done √√
# 429/2364 done √√
# 430/2364 done √√
# 431/2364 done √√
# 432/2364 done √√
# 433/2364 done √√
# 434/2364 done √√
# 435/2364 done √√
# 436/2364 done √√
# 437/2364 done √√
# 438/2364 done √√
# 439/2364 done √√
# 440/2364 done √√
# 441/2364 done √√
# 442/2364 done √√
# 443/2364 done √√
# 444/2364 done √√
# 445/2364 done √√
# 446/2364 done √√
# 447/2364 done √√
# 448/2364 done √√
# 449/2364 done √√
# 450/2364 done √√
# 451/2364 done √√
# 452/2364 done √√
# 453/2364 done √√
# 454/2364 done √√
# 455/2364 done √√
# 456/2364 done √√
# 457/2364 done √√
# 458/2364 done √√
# 459/2364 done √√
# 460/2364 done √√
# 461/2364 done √√
# 462/2364 done √√
# 463/2364 done √√
# 464/2364 done √√
# 465/2364 done √√
# 466/2364 done √√
# 467/2364 done √√
# 468/2364 done √√
# 469/2364 done √√
# 470/2364 done √√
# 471/2364 done √√
# 472/2364 done √√
# 473/2364 done √√
# 474/2364 done √√
# 475/2364 done √√
# 476/2364 done √√
# 477/2364 done √√
# 478/2364 done √√
# 479/2364 done √√
# 480/2364 done √√
# 481/2364 done √√
# 482/2364 done √√
# 483/2364 done √√
# 484/2364 done √√
# 485/2364 done √√
# 486/2364 done √√
# 487/2364 done √√
# 488/2364 done √√
# 489/2364 done √√
# 490/2364 done √√
# 491/2364 done √√
# 492/2364 done √√
# 493/2364 done √√
# 494/2364 done √√
# 495/2364 done √√
# 496/2364 done √√
# 497/2364 done √√
# 498/2364 done √√
# 499/2364 done √√
# 500/2364 done √√
# 501/2364 done √√
# 502/2364 done √√
# 503/2364 done √√
# 504/2364 done √√
# 505/2364 done √√
# 506/2364 done √√
# 507/2364 done √√
# 508/2364 done √√
# 509/2364 done √√
# 510/2364 done √√
# 511/2364 done √√
# 512/2364 done √√
# 513/2364 done √√
# 514/2364 done √√
# 515/2364 done √√
# 516/2364 done √√
# 517/2364 done √√
# 518/2364 done √√
# 519/2364 done √√
# 520/2364 done √√
# 521/2364 done √√
# 522/2364 done √√
# 523/2364 done √√
# 524/2364 done √√
# 525/2364 done √√
# 526/2364 done √√
# 527/2364 done √√
# 528/2364 done √√
# 529/2364 done √√
# 530/2364 done √√
# 531/2364 done √√
# 532/2364 done √√
# 533/2364 done √√
# 534/2364 done √√
# 535/2364 done √√
# 536/2364 done √√
# 537/2364 done √√
# 538/2364 done √√
# 539/2364 done √√
# 540/2364 done √√
# 541/2364 done √√
# 542/2364 done √√
# 543/2364 done √√
# 544/2364 done √√
# 545/2364 done √√
# 546/2364 done √√
# 547/2364 done √√
# 548/2364 done √√
# 549/2364 done √√
# 550/2364 done √√
# 551/2364 done √√
# 552/2364 done √√
# 553/2364 done √√
# 554/2364 done √√
# 555/2364 done √√
# 556/2364 done √√
# 557/2364 done √√
# 558/2364 done √√
# 559/2364 done √√
# 560/2364 done √√
# 561/2364 done √√
# 562/2364 done √√
# 563/2364 done √√
# 564/2364 done √√
# 565/2364 done √√
# 566/2364 done √√
# 567/2364 done √√
# 568/2364 done √√
# 569/2364 done √√
# 570/2364 done √√
# 571/2364 done √√
# 572/2364 done √√
# 573/2364 done √√
# 574/2364 done √√
# 575/2364 done √√
# 576/2364 done √√
# 577/2364 done √√
# 578/2364 done √√
# 579/2364 done √√
# 580/2364 done √√
# 581/2364 done √√
# 582/2364 done √√
# 583/2364 done √√
# 584/2364 done √√
# 585/2364 done √√
# 586/2364 done √√
# 587/2364 done √√
# 588/2364 done √√
# 589/2364 done √√
# 590/2364 done √√
# 591/2364 done √√
# 592/2364 done √√
# 593/2364 done √√
# 594/2364 done √√
# 595/2364 done √√
# 596/2364 done √√
# 597/2364 done √√
# 598/2364 done √√
# 599/2364 done √√
# 600/2364 done √√
# 601/2364 done √√
# 602/2364 done √√
# 603/2364 done √√
# 604/2364 done √√
# 605/2364 done √√
# 606/2364 done √√
# 607/2364 done √√
# 608/2364 done √√
# 609/2364 done √√
# 610/2364 done √√
# 611/2364 done √√
# 612/2364 done √√
# 613/2364 done √√
# 614/2364 done √√
# 615/2364 done √√
# 616/2364 done √√
# 617/2364 done √√
# 618/2364 done √√
# 619/2364 done √√
# 620/2364 done √√
# 621/2364 done √√
# 622/2364 done √√
# 623/2364 done √√
# 624/2364 done √√
# 625/2364 done √√
# 626/2364 done √√
# 627/2364 done √√
# 628/2364 done √√
# 629/2364 done √√
# 630/2364 done √√
# 631/2364 done √√
# 632/2364 done √√
# 633/2364 done √√
# 634/2364 done √√
# 635/2364 done √√
# 636/2364 done √√
# 637/2364 done √√
# 638/2364 done √√
# 639/2364 done √√
# 640/2364 done √√
# 641/2364 done √√
# 642/2364 done √√
# 643/2364 done √√
# 644/2364 done √√
# 645/2364 done √√
# 646/2364 done √√
# 647/2364 done √√
# 648/2364 done √√
# 649/2364 done √√
# 650/2364 done √√
# 651/2364 done √√
# 652/2364 done √√
# 653/2364 done √√
# 654/2364 done √√
# 655/2364 done √√
# 656/2364 done √√
# 657/2364 done √√
# 658/2364 done √√
# 659/2364 done √√
# 660/2364 done √√
# 661/2364 done √√
# 662/2364 done √√
# 663/2364 done √√
# 664/2364 done √√
# 665/2364 done √√
# 666/2364 done √√
# 667/2364 done √√
# 668/2364 done √√
# 669/2364 done √√
# 670/2364 done √√
# 671/2364 done √√
# 672/2364 done √√
# 673/2364 done √√
# 674/2364 done √√
# 675/2364 done √√
# 676/2364 done √√
# 677/2364 done √√
# 678/2364 done √√
# 679/2364 done √√
# 680/2364 done √√
# 681/2364 done √√
# 682/2364 done √√
# 683/2364 done √√
# 684/2364 done √√
# 685/2364 done √√
# 686/2364 done √√
# 687/2364 done √√
# 688/2364 done √√
# 689/2364 done √√
# 690/2364 done √√
# 691/2364 done √√
# 692/2364 done √√
# 693/2364 done √√
# 694/2364 done √√
# 695/2364 done √√
# 696/2364 done √√
# 697/2364 done √√
# 698/2364 done √√
# 699/2364 done √√
# 700/2364 done √√
# 701/2364 done √√
# 702/2364 done √√
# 703/2364 done √√
# 704/2364 done √√
# 705/2364 done √√
# 706/2364 done √√
# 707/2364 done √√
# 708/2364 done √√
# 709/2364 done √√
# 710/2364 done √√
# 711/2364 done √√
# 712/2364 done √√
# 713/2364 done √√
# 714/2364 done √√
# 715/2364 done √√
# 716/2364 done √√
# 717/2364 done √√
# 718/2364 done √√
# 719/2364 done √√
# 720/2364 done √√
# 721/2364 done √√
# 722/2364 done √√
# 723/2364 done √√
# 724/2364 done √√
# 725/2364 done √√
# 726/2364 done √√
# 727/2364 done √√
# 728/2364 done √√
# 729/2364 done √√
# 730/2364 done √√
# 731/2364 done √√
# 732/2364 done √√
# 733/2364 done √√
# 734/2364 done √√
# 735/2364 done √√
# 736/2364 done √√
# 737/2364 done √√
# 738/2364 done √√
# 739/2364 done √√
# 740/2364 done √√
# 741/2364 done √√
# 742/2364 done √√
# 743/2364 done √√
# 744/2364 done √√
# 745/2364 done √√
# 746/2364 done √√
# 747/2364 done √√
# 748/2364 done √√
# 749/2364 done √√
# 750/2364 done √√
# 751/2364 done √√
# 752/2364 done √√
# 753/2364 done √√
# 754/2364 done √√
# 755/2364 done √√
# 756/2364 done √√
# 757/2364 done √√
# 758/2364 done √√
# 759/2364 done √√
# 760/2364 done √√
# 761/2364 done √√
# 762/2364 done √√
# 763/2364 done √√
# 764/2364 done √√
# 765/2364 done √√
# 766/2364 done √√
# 767/2364 done √√
# 768/2364 done √√
# 769/2364 done √√
# 770/2364 done √√
# 771/2364 done √√
# 772/2364 done √√
# 773/2364 done √√
# 774/2364 done √√
# 775/2364 done √√
# 776/2364 done √√
# 777/2364 done √√
# 778/2364 done √√
# 779/2364 done √√
# 780/2364 done √√
# 781/2364 done √√
# 782/2364 done √√
# 783/2364 done √√
# 784/2364 done √√
# 785/2364 done √√
# 786/2364 done √√
# 787/2364 done √√
# 788/2364 done √√
# 789/2364 done √√
# 790/2364 done √√
# 791/2364 done √√
# 792/2364 done √√
# 793/2364 done √√
# 794/2364 done √√
# 795/2364 done √√
# 796/2364 done √√
# 797/2364 done √√
# 798/2364 done √√
# 799/2364 done √√
# 800/2364 done √√
# 801/2364 done √√
# 802/2364 done √√
# 803/2364 done √√
# 804/2364 done √√
# 805/2364 done √√
# 806/2364 done √√
# 807/2364 done √√
# 808/2364 done √√
# 809/2364 done √√
# 810/2364 done √√
# 811/2364 done √√
# 812/2364 done √√
# 813/2364 done √√
# 814/2364 done √√
# 815/2364 done √√
# 816/2364 done √√
# 817/2364 done √√
# 818/2364 done √√
# 819/2364 done √√
# 820/2364 done √√
# 821/2364 done √√
# 822/2364 done √√
# 823/2364 done √√
# 824/2364 done √√
# 825/2364 done √√
# 826/2364 done √√
# 827/2364 done √√
# 828/2364 done √√
# 829/2364 done √√
# 830/2364 done √√
# 831/2364 done √√
# 832/2364 done √√
# 833/2364 done √√
# 834/2364 done √√
# 835/2364 done √√
# 836/2364 done √√
# 837/2364 done √√
# 838/2364 done √√
# 839/2364 done √√
# 840/2364 done √√
# 841/2364 done √√
# 842/2364 done √√
# 843/2364 done √√
# 844/2364 done √√
# 845/2364 done √√
# 846/2364 done √√
# 847/2364 done √√
# 848/2364 done √√
# 849/2364 done √√
# 850/2364 done √√
# 851/2364 done √√
# 852/2364 done √√
# 853/2364 done √√
# 854/2364 done √√
# 855/2364 done √√
# 856/2364 done √√
# 857/2364 done √√
# 858/2364 done √√
# 859/2364 done √√
# 860/2364 done √√
# 861/2364 done √√
# 862/2364 done √√
# 863/2364 done √√
# 864/2364 done √√
# 865/2364 done √√
# 866/2364 done √√
# 867/2364 done √√
# 868/2364 done √√
# 869/2364 done √√
# 870/2364 done √√
# 871/2364 done √√
# 872/2364 done √√
# 873/2364 done √√
# 874/2364 done √√
# 875/2364 done √√
# 876/2364 done √√
# 877/2364 done √√
# 878/2364 done √√
# 879/2364 done √√
# 880/2364 done √√
# 881/2364 done √√
# 882/2364 done √√
# 883/2364 done √√
# 884/2364 done √√
# 885/2364 done √√
# 886/2364 done √√
# 887/2364 done √√
# 888/2364 done √√
# 889/2364 done √√
# 890/2364 done √√
# 891/2364 done √√
# 892/2364 done √√
# 893/2364 done √√
# 894/2364 done √√
# 895/2364 done √√
# 896/2364 done √√
# 897/2364 done √√
# 898/2364 done √√
# 899/2364 done √√
# 900/2364 done √√
# 901/2364 done √√
# 902/2364 done √√
# 903/2364 done √√
# 904/2364 done √√
# 905/2364 done √√
# 906/2364 done √√
# 907/2364 done √√
# 908/2364 done √√
# 909/2364 done √√
# 910/2364 done √√
# 911/2364 done √√
# 912/2364 done √√
# 913/2364 done √√
# 914/2364 done √√
# 915/2364 done √√
# 916/2364 done √√
# 917/2364 done √√
# 918/2364 done √√
# 919/2364 done √√
# 920/2364 done √√
# 921/2364 done √√
# 922/2364 done √√
# 923/2364 done √√
# 924/2364 done √√
# 925/2364 done √√
# 926/2364 done √√
# 927/2364 done √√
# 928/2364 done √√
# 929/2364 done √√
# 930/2364 done √√
# 931/2364 done √√
# 932/2364 done √√
# 933/2364 done √√
# 934/2364 done √√
# 935/2364 done √√
# 936/2364 done √√
# 937/2364 done √√
# 938/2364 done √√
# 939/2364 done √√
# 940/2364 done √√
# 941/2364 done √√
# 942/2364 done √√
# 943/2364 done √√
# 944/2364 done √√
# 945/2364 done √√
# 946/2364 done √√
# 947/2364 done √√
# 948/2364 done √√
# 949/2364 done √√
# 950/2364 done √√
# 951/2364 done √√
# 952/2364 done √√
# 953/2364 done √√
# 954/2364 done √√
# 955/2364 done √√
# 956/2364 done √√
# 957/2364 done √√
# 958/2364 done √√
# 959/2364 done √√
# 960/2364 done √√
# 961/2364 done √√
# 962/2364 done √√
# 963/2364 done √√
# 964/2364 done √√
# 965/2364 done √√
# 966/2364 done √√
# 967/2364 done √√
# 968/2364 done √√
# 969/2364 done √√
# 970/2364 done √√
# 971/2364 done √√
# 972/2364 done √√
# 973/2364 done √√
# 974/2364 done √√
# 975/2364 done √√
# 976/2364 done √√
# 977/2364 done √√
# 978/2364 done √√
# 979/2364 done √√
# 980/2364 done √√
# 981/2364 done √√
# 982/2364 done √√
# 983/2364 done √√
# 984/2364 done √√
# 2011/2364 done √√
# 2012/2364 done √√
# 2013/2364 done √√
# 2014/2364 done √√
# 2015/2364 done √√
# 2016/2364 done √√
# 2017/2364 done √√
# 2018/2364 done √√
# 2019/2364 done √√
# 2020/2364 done √√
# 2021/2364 done √√
# 2022/2364 done √√
# 2023/2364 done √√
# 2024/2364 done √√
# 2025/2364 done √√
# 2026/2364 done √√
# 2027/2364 done √√
# 2028/2364 done √√
# 2029/2364 done √√
# 2030/2364 done √√
# 2031/2364 done √√
# 2032/2364 done √√
# 2033/2364 done √√
# 2034/2364 done √√
# 2035/2364 done √√
# 2036/2364 done √√
# 2037/2364 done √√
# 2038/2364 done √√
# 2039/2364 done √√
# 2040/2364 done √√
# 2041/2364 done √√
# 2042/2364 done √√
# 2043/2364 done √√
# 2044/2364 done √√
# 2045/2364 done √√
# 2046/2364 done √√
# 2047/2364 done √√
# 2048/2364 done √√
# 2049/2364 done √√
# 2050/2364 done √√
# 2051/2364 done √√
# 2052/2364 done √√
# 2053/2364 done √√
# 2054/2364 done √√
# 2055/2364 done √√
# 2056/2364 done √√
# 2057/2364 done √√
# 2058/2364 done √√
# 2059/2364 done √√
# 2060/2364 done √√
# 2061/2364 done √√
# 2062/2364 done √√
# 2063/2364 done √√
# 2064/2364 done √√
# 2065/2364 done √√
# 2066/2364 done √√
# 2067/2364 done √√
# 2068/2364 done √√
# 2069/2364 done √√
# 2070/2364 done √√
# 2071/2364 done √√
# 2072/2364 done √√
# 2073/2364 done √√
# 2074/2364 done √√
# 2075/2364 done √√
# 2076/2364 done √√
# 2077/2364 done √√
# 2078/2364 done √√
# 2079/2364 done √√
# 2080/2364 done √√
# 2081/2364 done √√
# 2082/2364 done √√
# 2083/2364 done √√
# 2084/2364 done √√
# 2085/2364 done √√
# 2086/2364 done √√
# 2087/2364 done √√
# 2088/2364 done √√
# 2089/2364 done √√
# 2090/2364 done √√
# 2091/2364 done √√
# 2092/2364 done √√
# 2093/2364 done √√
# 2094/2364 done √√
# 2095/2364 done √√
# 2096/2364 done √√
# 2097/2364 done √√
# 2098/2364 done √√
# 2099/2364 done √√
# 2100/2364 done √√
# 2101/2364 done √√
# 2102/2364 done √√
# 2103/2364 done √√
# 2104/2364 done √√
# 2105/2364 done √√
# 2106/2364 done √√
# 2107/2364 done √√
# 2108/2364 done √√
# 2109/2364 done √√
# 2110/2364 done √√
# 2111/2364 done √√
# 2112/2364 done √√
# 2113/2364 done √√
# 2114/2364 done √√
# 2115/2364 done √√
# 2116/2364 done √√
# 2117/2364 done √√
# 2118/2364 done √√
# 2119/2364 done √√
# 2120/2364 done √√
# 2121/2364 done √√
# 2122/2364 done √√
# 2123/2364 done √√
# 2124/2364 done √√
# 2125/2364 done √√
# 2126/2364 done √√
# 2127/2364 done √√
# 2128/2364 done √√
# 2129/2364 done √√
# 2130/2364 done √√
# 2131/2364 done √√
# 2132/2364 done √√
# 2133/2364 done √√
# 2134/2364 done √√
# 2135/2364 done √√
# 2136/2364 done √√
# 2137/2364 done √√
# 2138/2364 done √√
# 2139/2364 done √√
# 2140/2364 done √√
# 2141/2364 done √√
# 2142/2364 done √√
# 2143/2364 done √√
# 2144/2364 done √√
# 2145/2364 done √√
# 2146/2364 done √√
# 2147/2364 done √√
# 2148/2364 done √√
# 2149/2364 done √√
# 2150/2364 done √√
# 2151/2364 done √√
# 2152/2364 done √√
# 2153/2364 done √√
# 2154/2364 done √√
# 2155/2364 done √√
# 2156/2364 done √√
# 2157/2364 done √√
# 2158/2364 done √√
# 2159/2364 done √√
# 2160/2364 done √√
# 2161/2364 done √√
# 2162/2364 done √√
# 2163/2364 done √√
# 2164/2364 done √√
# 2165/2364 done √√
# 2166/2364 done √√
# 2167/2364 done √√
# 2168/2364 done √√
# 2169/2364 done √√
# 2170/2364 done √√
# 2171/2364 done √√
# 2172/2364 done √√
# 2173/2364 done √√
# 2174/2364 done √√
# 2175/2364 done √√
# 2176/2364 done √√
# 2177/2364 done √√
# 2178/2364 done √√
# 2179/2364 done √√
# 2180/2364 done √√
# 2181/2364 done √√
# 2182/2364 done √√
# 2183/2364 done √√
# 2184/2364 done √√
# 2185/2364 done √√
# 2186/2364 done √√
# 2187/2364 done √√
# 2188/2364 done √√
# 2189/2364 done √√
# 2190/2364 done √√
# 2191/2364 done √√
# 2192/2364 done √√
# 2193/2364 done √√
# 2194/2364 done √√
# 2195/2364 done √√
# 2196/2364 done √√
# 2197/2364 done √√
# 2198/2364 done √√
# 2199/2364 done √√
# 2200/2364 done √√
# 2201/2364 done √√
# 2202/2364 done √√
# 2203/2364 done √√
# 2204/2364 done √√
# 2205/2364 done √√
# 2206/2364 done √√
# 2207/2364 done √√
# 2208/2364 done √√
# 2209/2364 done √√
# 2210/2364 done √√
# 2211/2364 done √√
# 2212/2364 done √√
# 2213/2364 done √√
# 2214/2364 done √√
# 2215/2364 done √√
# 2216/2364 done √√
# 2217/2364 done √√
# 2218/2364 done √√
# 2219/2364 done √√
# 2220/2364 done √√
# 2221/2364 done √√
# 2222/2364 done √√
# 2223/2364 done √√
# 2224/2364 done √√
# 2225/2364 done √√
# 2226/2364 done √√
# 2227/2364 done √√
# 2228/2364 done √√
# 2229/2364 done √√
# 2230/2364 done √√
# 2231/2364 done √√
# 2232/2364 done √√
# 2233/2364 done √√
# 2234/2364 done √√
# 2235/2364 done √√
# 2236/2364 done √√
# 2237/2364 done √√
# 2238/2364 done √√
# 2239/2364 done √√
# 2240/2364 done √√
# 2241/2364 done √√
# 2242/2364 done √√
# 2243/2364 done √√
# 2244/2364 done √√
# 2245/2364 done √√
# 2246/2364 done √√
# 2247/2364 done √√
# 2248/2364 done √√
# 2249/2364 done √√
# 2250/2364 done √√
# 2251/2364 done √√
# 2252/2364 done √√
# 2253/2364 done √√
# 2254/2364 done √√
# 2255/2364 done √√
# 2256/2364 done √√
# 2257/2364 done √√
# 2258/2364 done √√
# 2259/2364 done √√
# 2260/2364 done √√
# 2261/2364 done √√
# 2262/2364 done √√
# 2263/2364 done √√
# 2264/2364 done √√
# 2265/2364 done √√
# 2266/2364 done √√
# 2267/2364 done √√
# 2268/2364 done √√
# 2269/2364 done √√
# 2270/2364 done √√
# 2271/2364 done √√
# 2272/2364 done √√
# 2273/2364 done √√
# 2274/2364 done √√
# 2275/2364 done √√
# 2276/2364 done √√
# 2277/2364 done √√
# 2278/2364 done √√
# 2279/2364 done √√
# 2280/2364 done √√
# 2281/2364 done √√
# 2282/2364 done √√
# 2283/2364 done √√
# 2284/2364 done √√
# 2285/2364 done √√
# 2286/2364 done √√
# 2287/2364 done √√
# 2288/2364 done √√
# 2289/2364 done √√
# 2290/2364 done √√
# 2291/2364 done √√
# 2292/2364 done √√
# 2293/2364 done √√
# 2294/2364 done √√
# 2295/2364 done √√
# 2296/2364 done √√
# 2297/2364 done √√
# 2298/2364 done √√
# 2299/2364 done √√
# 2300/2364 done √√
# 2301/2364 done √√
# 2302/2364 done √√
# 2303/2364 done √√
# 2304/2364 done √√
# 2305/2364 done √√
# 2306/2364 done √√
# 2307/2364 done √√
# 2308/2364 done √√
# 2309/2364 done √√
# 2310/2364 done √√
# 2311/2364 done √√
# 2312/2364 done √√
# 2313/2364 done √√
# 2314/2364 done √√
# 2315/2364 done √√
# 2316/2364 done √√
# 2317/2364 done √√
# 2318/2364 done √√
# 2319/2364 done √√
# 2320/2364 done √√
# 2321/2364 done √√
# 2322/2364 done √√
# 2323/2364 done √√
# 2324/2364 done √√
# 2325/2364 done √√
# 2326/2364 done √√
# 2327/2364 done √√
# 2328/2364 done √√
# 2329/2364 done √√
# 2330/2364 done √√
# 2331/2364 done √√
# 2332/2364 done √√
# 2333/2364 done √√
# 2334/2364 done √√
# 2335/2364 done √√
# 2336/2364 done √√
# 2337/2364 done √√
# 2338/2364 done √√
# 2339/2364 done √√
# 2340/2364 done √√
# 2341/2364 done √√
# 2342/2364 done √√
# 2343/2364 done √√
# 2344/2364 done √√
# 2345/2364 done √√
# 2346/2364 done √√
# 2347/2364 done √√
# 2348/2364 done √√
# 2349/2364 done √√
# 2350/2364 done √√
# 2351/2364 done √√
# 2352/2364 done √√
# 2353/2364 done √√
# 2354/2364 done √√
# 2355/2364 done √√
# 2356/2364 done √√
# 2357/2364 done √√
# 2358/2364 done √√
# 2359/2364 done √√
# 2360/2364 done √√
# 2361/2364 done √√
# 2362/2364 done √√
# 2363/2364 done √√
# ENDING

# %%
df.head()

# %%
df.to_csv('asr_boosted.csv',index=False)

# %%
import pandas as pd
df=pd.read_csv('asr_boosted.csv')
df.head()
# Out:
#                                               CALLID  \
# 0  cs01M-RE00bcf8e1f2c6d1c6573f18ade20ec956_A_000...
# 1  cs01M-RE00bcf8e1f2c6d1c6573f18ade20ec956_A_015...
# 2  cs01M-RE0f4543b94c7a5953871ac37cbc47a25f_B_000...
# 3  cs01M-RE0f4543b94c7a5953871ac37cbc47a25f_B_004...
# 4  cs01M-RE17b84c6cb32b4392ba3096982d24fbba_B_000...
#
#                                                  ASR  \
# 0  hi i'm in butter oh we had to go see it instea...
# 1  ah i don't know if i make it uh oklahoma but i...
# 2                                                i\n
# 3  sorry hello come out my uncle bill go through ...
# 4                                          so what\n
#
#                                          ASR_boosted       asr_ner  \
# 0  hi i'm in butter oh we have to go see it inste...           NaN
# 1  ah i don't know if i make it a oklahoma but i ...  ['oklahoma']
# 2                                                i\n           NaN
# 3  so they come out with my uncle bill go through...           NaN
# 4                                          so what\n           NaN
#
#   asr_boosted_ner asrboosted_person asrboosted_location asrboosted_time
# 0             NaN                []                  []              []
# 1    ['oklahoma']                []        ['oklahoma']              []
# 2             NaN                []                  []              []
# 3             NaN                []                  []              []
# 4             NaN                []                  []              []

# %%
d=pd.read_csv('/content/yaml_new.csv')
d.head()
# Out:
#                                               CALLID  \
# 0  de03M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 1  cs06M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 2  de03M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 3  cs06M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 4  de03M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
#
#                                           transcript ner_person ner_location  \
# 0                                             hello?         []           []
# 1                       hello? can you hear me well?         []           []
# 2          yes. hi. hi. i can hear you. how are you?         []           []
# 3  hi. i'm fine. i just wanted to tell you sorry ...         []           []
# 4                      yeah. no problem. no problem.         []           []
#
#   ner_time
# 0       []
# 1       []
# 2       []
# 3       []
# 4       []

# %%
df1=pd.merge(df,d,on='CALLID',how='left')

# %%
print(df.shape,d.shape,df1.shape)
# Out:
# (2364, 8) (2747, 5) (2364, 12)

# %%
df1.to_csv('asr_boosted_new.csv',index=False)

# %% [markdown]
# ## PRECISION RECALL F1 TP FP FN - METRIC RESULTS AND FREQ

# %%
import pandas as pd
df=pd.read_csv('/content/new_manual.csv')
df.head()
# Out:
#                                               CALLID  \
# 0  de03M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 1  cs06M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 2  de03M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 3  cs06M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 4  de03M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
#
#                                           transcript ner_person ner_location  \
# 0                                             hello?         []           []
# 1                       hello? can you hear me well?         []           []
# 2          yes. hi. hi. I can hear you. how are you?         []           []
# 3  hi. I'm fine. I just wanted to tell you sorry ...         []           []
# 4                      yeah. no problem. no problem.         []           []
#
#   ner_time manual_person manual_location manual_time
# 0       []            []              []          []
# 1       []            []              []          []
# 2       []            []              []          []
# 3       []            []              []          []
# 4       []            []              []          []

# %%
import numpy as np
import string
df['tp']=np.empty((len(df), 0)).tolist()
df['fp']=np.empty((len(df), 0)).tolist()
df['fn']=np.empty((len(df), 0)).tolist()
df.head(2)
# Out:
#                                               CALLID  \
# 0  de03M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 1  cs06M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
#
#                      transcript ner_person ner_location ner_time  \
# 0                        hello?         []           []       []
# 1  hello? can you hear me well?         []           []       []
#
#   manual_person manual_location manual_time  tp  fp  fn
# 0            []              []          []  []  []  []
# 1            []              []          []  []  []  []

# %%
from ast import literal_eval
from difflib import SequenceMatcher
for index , row in df.iterrows():
  r=row['ner_time']
  h=row['manual_time']


  if isinstance(r,str):
    r=literal_eval(r)
  else:
    r=[]
  
  if isinstance(h,str):
    h=literal_eval(h)
  else:
    h=[]

  #h=[''.join(c for c in s if c not in string.punctuation) for s in h]

  FN= [item for item in r if item not in h]
  FP= [item for item in h if item not in r]
  TP= [x for x in r if x in h]

# r is ground truth
# h is pred 

  '''for i in r:
    for j in h:
      sim=SequenceMatcher(a=i,b=j).ratio()
      if sim>0.5:
        if j not in TP:
          TP.append(j)
        if i in FN:
          FN.remove(i)
        else:
          pass
        if j in FP:
          FP.remove(j)'''
                

  df.at[index,'fp']=FP
  df.at[index,'fn']=FN
  df.at[index,'tp']=TP

# %%
df.head()
# Out:
#                                               CALLID  \
# 0  de03M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 1  cs06M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 2  de03M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 3  cs06M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
# 4  de03M-kvkygrcg--zmca42-19zxkdrp3d41yn2mifm_UDP...
#
#                                           transcript ner_person ner_location  \
# 0                                             hello?         []           []
# 1                       hello? can you hear me well?         []           []
# 2          yes. hi. hi. I can hear you. how are you?         []           []
# 3  hi. I'm fine. I just wanted to tell you sorry ...         []           []
# 4                      yeah. no problem. no problem.         []           []
#
#   ner_time manual_person manual_location manual_time  tp  fp  fn
# 0       []            []              []          []  []  []  []
# 1       []            []              []          []  []  []  []
# 2       []            []              []          []  []  []  []
# 3       []            []              []          []  []  []  []
# 4       []            []              []          []  []  []  []

# %%
p=[]
r=[]
f=[]
wer=[]
tpn=[]
fpn=[]
fnn=[]
tp1=0
fp1=0
fn1=0
for i , row in df.iterrows():
  manual=row['ner_time'] 
  if isinstance(manual,str):
    manual=literal_eval(manual)
  else:
    manual=[]

  tp=row['tp']
  fp=row['fp']
  fn=row['fn']
  #w=row['WER']

  tp=[x for x in tp if x != []]
  fp=[x for x in fp if x != []]
  fn=[x for x in fn if x != []]



  if len(manual)>0:
    tpn.append(tp)
    fpn.append(fp)
    fnn.append(fn)


    tp=len(tp)
    fp=len(fp)
    fn=len(fn)
    

    tp1+=tp
    fp1+=fp
    fn1+=fn

    try:
      precision=tp/(tp+fp)
    except:
      precision=0
    try:
      recall=tp/(tp+fn)
    except:
      recall=0
    try:
      f1=(2*precision*recall)/(precision+recall)
    except:
      f1=0
  
    p.append(precision)
    r.append(recall)
    f.append(f1)
    #wer.append(w)

# %%
from statistics import mean
print(tp1,fp1,fn1)
precision=tp1/(tp1+fp1)
recall=tp1/(tp1+fn1)
f1=(2*precision*recall)/(precision+recall)
print(precision,recall,f1)
# Out:
# 174 55 93
# 0.759825327510917 0.651685393258427 0.7016129032258065

# %%
tpn=[x for x in tpn if x != []]
tpn = [item for sublist in tpn for item in sublist]
fpn=[x for x in fpn if x != []]
fpn = [item for sublist in fpn for item in sublist]
fnn=[x for x in fnn if x != []]
fnn = [item for sublist in fnn for item in sublist]
print(len(tpn),len(fpn),len(fnn))
# Out:
# 174 55 93

# %%
from collections import Counter
def s(dict1):
  sorted_dict = {}
  sorted_keys = sorted(dict1, key=dict1.get)  
  for w in sorted_keys:
    sorted_dict[w] = dict1[w]
  print(sorted_dict)

print(s(Counter(tpn)))
print()
print(s(Counter(fpn)))
print()
print(s(Counter(fnn)))
# Out:
# {'the week': 1, 'four weeks': 1, 'fifteen minutes': 1, 'thirty minutes': 1, 'fourteen fifteen': 1, 'late next week': 1, 'these last few weeks': 1, 'two weeks': 1, 'seven days': 1, 'about twenty minutes': 1, 'four hours': 1, 'Tomorrow': 1, 'tommorow': 1, 'the beginning of December': 1, 'the beginning of the year': 1, 'the end of the year': 1, 'last last year': 1, 'seven': 1, 'fifteen minutes before':
more hours': 1, 'on December eighth': 1, 'beginning of two thousand nineteen': 1, 'a few minute': 1, 'ten past seven': 1, 'on the fiftieth': 1, 'seven': 1, 'two or three minutes': 1, 'one second': 1, 'the new year': 1, 'Christmas eve': 1, 'one hour': 1, 'two hours': 1, 'seventeenth': 1, 'twenty first': 1, 'five days': 1, 'a week': 1, 'after four PM': 1, 'within one hour': 1, 'in ten minutes': 1, 'a couple of days': 1, 'at eleven': 2, 'the next month': 2, 'January': 2, 'tonight': 2, 'six thirty': 2, 'six thirty P M': 2, 'Christmas': 2, 'three minutes': 2, 'three thirty': 2, 'yesterday': 3, 'this year': 3, 'this weekend': 4, 'this morning': 4, 'today': 6, 'tomorrow': 6}
# None

# %%
per=[]
loc=[]
ti=[]
for i , row in df.iterrows():
  p=row['ner_person']
  l=row['ner_location']
  t=row['ner_time']

  if isinstance(p,str):
    p=literal_eval(p)

  if isinstance(l,str):
    l=literal_eval(l)
  if isinstance(t,str):
    t=literal_eval(t)

  per.append(p)
  loc.append(l)
  ti.append(t)

# %%
a=[]
for i in per:
  for j in i:
    a.append(j)
print(f'{len(a)} person')
print(a)
a=[]
for i in loc:
  for j in i:
    a.append(j)
print(f'{len(a)} location')
print(a)
a=[]
for i in ti:
  for j in i:
    a.append(j)
print(f'{len(a)} time')
print(a)
# Out:
# 239 person
# ['jakub', 'lila', 'kuki', 'dick', 'felix', 'felix', 'felix', 'ivan', 'adam', 'adam', 'kuba', 'adam', 'petr', 'adam', 'michael', 'jakub', 'adam', 'adam', 'jakub', 'michal', 'michal', 'adam', 'adam', 'larry david', 'jakub', 'adam', 'jimmy carr', 'adam', 'adam', 'adam', 'adam', 'adam', 'adam junior', 'adam', 'michal', 'jakub', 'michale', 'michal', 'šárka', 'michal', 'michal', 'michal', 'johan', 'saeed', 'christoph', 'mael', 'saeed', 'petr', 'petr', 'mael', 'julia', 'petr', 'yan', 'yan', 'petr', 'james', 'marko', 'marko', 'slava', 'slava', 'marko', 'marko', 'slava', 'slava', 'katja', 'kristýna', 'kristýna', 'donald trump', 'joe biden', 'hillary', 'donald trump', 'kristýna', 'kristýna', 'rom', 'kristýna', 'kristýna', 'evžen', 'evžen', 'paul', 'marek', 'marek', 'paul', 'marek', 'tom', 'tom', 'michal', 'kristýna', 'michal', 'kristina', 'marko', 'jakub', 'yan', 'kuba', 'kuba', 'kristýna', 'adam', 'marek', 'tom', 'kristi', 'evžen', 'kristi', 'kuba', 'michal', 'michael', 'michal', 'kristýna', 'michal david', 'helenka', 'kristýna', 'michal', 'kika', 'damir', 'slava', 'marko', 'zijian', 'spiros', 'costas', 'spiros', 'spiros', 'spiros', 'costas', 'costas', 'stella', 'costas', 'costas', 'michael', 'kuba', 'adam', 'kuba', 'adam', 'mark', 'gordon ramsay', 'kuba', 'adam', 'adam', 'michael', 'mesi', 'mesi', 'kuba', 'kuba', 'kuba', 'paul', 'kuba', 'adam', 'adam junior', 'adam junior', 'kuba', 'kristýna', 'paul', 'donald trump', 'kristýna', 'kristýna', 'kristýna', 'kristýna', 'paul', 'katka', 'paul', 'kristýna', 'ron', 'ronald', 'paul', 'kristýna', 'kristýna', 'kristýna', 'kristýna', 'paul', 'coodly', 'oodly', 'shmoodly', 'kristýna', 'johan', 'damir', 'zijian', 'damir', 'slava', 'johan', 'johan', 'johan', 'zahra', 'johan', 'johan', 'damir', 'peter', 'johan', 'johan', 'david', 'graham', 'graham', 'dave', 'johan', 'pat', 'david', 'david', 'dave', 'graham', 'dave', 'graham', 'graham', 'dave', 'dave', 'dave', 'pat', 'dave', 'jack', 'jill', 'pierre', 'christoph', 'abbas', 'petr', 'saeed', 'johan', 'zahra', 'zahra ahmadi', 'johan', 'yan', 'petr', 'adam', 'petr', 'petr', 'shi shen liu', 'petr', 'mael', 'petr', 'petr', 'mael', 'mael', 'max', 'petr', 'pedro', 'dick', 'dick', 'tesla', 'leonardo', 'leni', 'pedro', 'igos', 'igos', 'felix', 'kristýna']
# 129 location
# ['brno', 'prague', 'prague', 'moldova', 'česká', 'strážní', 'brno', 'prague', 'hrouda', 'dukla', 'florence', 'hostivař railway station', 'maniny', 'hlavák', 'netherlands', 'serbia', 'hawai', 'france', 'paris', 'switzerland', 'germany', 'czech republic', 'munich', 'brno', 'vienna', 'munich', 'munich', 'munich', 'germany', 'vienna', 'munich', 'prague', 'u s', 'u s', 'prague', 'prague', 'brno', 'prague', 'prague', 'brno', 'hotel international', 'fleda club', 'fleda', 'munich', 'serbia', 'kralova', 'asia', 'florida', 'brno', 'brno', 'brno', 'flora', 'skalka', 'maniny', 'cottage', 'skalka', 'munich', 'munich', 'the east train station', 'gambino hotel', 'werkviertel', 'germany', 'munich', 'the english garden', 'der englischer garten', 'the englischen garten', 'germany', 'munich', 'the english garden', 'der englische garten', 'the englischen garten', 'munich', 'the train station', 'the main train station', 'english garden', 'munich', 'teheran', 'teheran', 'iran', 'munich', 'munich', 'munich', 'crete', 'the czech republic', 'brno', 'munich', 'munich', 'hyperion hotel', 'munich', 'athens', 'latin america', 'venezuela', 'three storks restaurant', 'three storks', 'the u s', 'the u s', 'prague', 'prague', 'prague', 'germany', 'zar', 'marien platz', 'china', 'vietnam', 'northern italy', 'hyperion', 'idiap', 'idiap', 'idiap', 'idiap', 'idiap', 'munich', 'marienplatz', 'altenstadt', 'the marien square', 'altstadt', 'marionplatz', 'marionplatz', 'marionplatz', 'munich', 'hyperion hotel', 'paris', 'paris', 'romania', 'manina', 'kaserak', 'hlavák', 'main station', 'prague']
# 267 time
# ['half an hour', 'in ten minutes', 'fourteen fifteen', 'half past three', 'tonight', 'two or three fifteen', "eleven o'clock", 'at eleven', 'beginning of two thousand nineteen', 'today', 'four weeks', 'tomorrow', 'next year', 'three minutes', 'three minutes', 'one second', 'one minute', 'the very first day', 'tomorrow', 'tomorrow', 'christmas', 'yesterday evening', 'thirty minutes', 'the beginning of the year', 'q four', 'february', 'february', 'end of this year', 'six thirty', 'ten', 'six thirty. p m', 'six thirty p m', 'tomorrow', 'six thirty tomorrow', 'one thirty eight p m', 'two hours', 'two hours later', 'three thirty', 'this year', 'this year', 'three thirty', 'next week', 'yesterday', 'yesterday', 'five days', 'five days', 'tomorrow', 'tomorrow', 'tommorow', 'yesterday', 'nine forty five', 'today', 'tomorrow', 'today', 'tomorrow', 'yesterday', 'yesterday', 'half past three', 'half past three', 'yesterday', 'the end of the next week', 'the week', 'the end of the next week', 'three days', 'tomorrow', 'three days', 'five days', 'five days', 'a week', 'few days', 'a week', 'few days', 'a couple of days', 'an hour', 'one hour', 'december', 'christmas', 'today', 'after four pm', 'within one hour', 'today', 'a new year', 'today', 'monday', 'monday', 'a few days ago', 'yesterday', 'today', 'two hours', 'next week', 'two days', 'two or three minutes', 'the new year', 'today', 'christmas eve', 'three thirty', 'two more hours', 'three thirty', 'today', 'today', 'this year', 'twenty five minutes', 'friday', 'saturday', 'in fifteen minutes', 'one hour', 'one hour', 'ten past seven', 'on the fiftieth', 'friday', 'in an hour', 'the next few days', 'couple of days', 'the next few days', 'couple of days', 'seven days', 'next week', 'midnight', 'tomorrow', 'today', 'today', 'next week', 'wednesday', 'thursday', 'thursday', 'wednesday', 'thursday', 'end of bildday after tomorrow', 'yesterday', 'next week', 'next week', 'two p m', 'wednesday', 'next week', 'thursday', 'next week', 'the end of tomorrow', 'next week', 'next week', 'wednesday', 'thursday noon', 'in ten or fifteen minutes', 'about twenty minutes', 'four hours', 'two pm', 'five or ten minutes', 'the beginning of december', 'on december eighth', 'december ninth', 'fifteen minutes', 'january', 'january', 'the end of the year', 'january', 'february', 'january', 'february', 'february', 'a month', "ten o'clock", 'six thirty', 'six thirty', 'six thirty', 'ten', 'six thirty', 'six thirty p m', 'three days', 'three days', 'next week', 'a couple of months', 'this weekend', 'saturday', 'yesterday', 'today', 'today', 'ten days', 'the next couple of weeks', 'christmas', 'the end of this week', 'yesterday', 'yesterday', 'yesterday', 'this weekend', 'this morning', 'two hour', 'the next day', 'christmas', 'three minutes', 'the next couple of minutes', 'seven or eight minutes', 'this morning', 'this morning', 'a week or two', 'one hour', 'tomorrow', 'seven thirty', 'eight', 'like two hours', 'today', 'twenty minutes', 'seven thirty', 'seven thirty', 'seven thirty', 'a few minutes', 'four five minutes', 'some minutes ago', 'tonight', 'tomorrow', 'tomorrow', 'a couple of minutes', 'a few minutes', 'the next few minutes', 'the next couple of minutes', 'tomorrow', 'tomorrow', 'five minutes', 'late next week', 'next week', 'two weeks', 'tomorrow', 'ten a m.', 'couple of minutes', 'the coming days', 'these last few weeks', 'tomorrow', 'thursday', 'half an hour before', 'fifteen minutes before', 'two months ago', 'today', 'tomorrow', 'one minute', 'tommorow', 'seven', 'seven thirty', 'seven thirty', 'seven', 'eight', 'today', 'two hours', 'today', 'christmas', 'a week', 'last last year', 'tomorrow', 'january', 'seventeenth', 'twenty first', 'five days', 'this morning', 'ten', 'the next month', 'this weekend', 'a few minute', 'next week', 'next week', 'the next month', 'this weekend', 'tomorrow', 'twelve', 'at two', 'two minutes ago', 'next weekend saturday', 'friday', 'tomorrow', 'at eleven', 'five ...

# %%
166+101
# Out:
# 267
